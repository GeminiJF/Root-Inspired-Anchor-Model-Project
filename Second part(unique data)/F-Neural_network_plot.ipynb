# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df2 = pd.read_csv("Neural Network data new.csv")
df2.drop(columns = ["Unnamed: 3", "Unnamed: 4", "Unnamed: 5", "Unnamed: 6"], inplace = True)
df2.head()
# Out:
#     epoch  Accuracy(selu)  Accuracy(Tanh)
# 0  1000.0          68.423         60.8900
# 1  2000.0          70.908         66.9635
# 2  3000.0          72.490         65.6575
# 3  4000.0          74.977         68.9170
# 4  5000.0          76.476         69.3290

# %%
x2 = df2["epoch"]
y2 = df2["Accuracy(Tanh)"]
y3 = df2["Accuracy(selu)"]

# %%
fig = plt.figure(figsize=(20,11))
plt.xlabel("number of iteration", fontsize = 25)
plt.ylabel("Accuracy", fontsize = 25)
plt.title("Neural Network", fontsize = 25)
plt.plot(x2, y2, color = "orange", label = "Activation: Hyperbolic Tangent")
plt.plot(x2, y3, color = "blue", label = "Activation: Scale Exponential Linear Unit")
plt.legend(loc = 2, prop = {"size" : 20})
plt.ylim(0, 100)

plt.tick_params(axis="x", colors='r', labelsize = 30)
plt.tick_params(axis="y", colors = "b" , labelsize = 20)
plt.ylim(50, 90)

plt.savefig("FNN3a_plot.png")
