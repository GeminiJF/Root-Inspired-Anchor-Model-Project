# %%
import pandas as pd
df = pd.read_excel("project_dataset.xlsx")
df.drop(columns = ["Unnamed: 24", "P_SLIPLINE [N]", "P_slip/gAH", "H/2b_updated","gammaAH_updated", "Unnamed: 30", "file"], inplace = True)
df.dropna(axis = 0, inplace = True)

# %%
df.head()
# Out:
#   n [count]  α [°]  L [mm]  H [mm]   b [mm]  H/2b [ ]    Ls [mm]  d [mm]  \
# 0         3     15    75.0    90.0  19.4114    2.3182  17.555563     5.0
# 1         3     15    50.0    90.0  12.9410    3.4773  41.703709     5.0
# 2         6     15    75.0    90.0  19.4114    2.3182  17.555563     5.0
# 3         6     15    50.0    90.0  12.9410    3.4773  41.703709     5.0
# 4         F     15    75.0    90.0  19.4114    2.3182  17.555563     5.0
#
#    P [ ]  2π/n [rad]  ...  γAH' [N]     Nγ [ ]   Vroot [mm3]  F/Nroot [ ]  \
# 0    1.0    2.094395  ...  1.264982   7.178479   4534.350557   185.583710
# 1    1.0    2.094395  ...  0.630942  13.881967   3535.876732   229.552206
# 2    1.0    1.047198  ...  1.264982   9.291625   8267.564868   131.745733
# 3    1.0    1.047198  ...  0.630942  17.113597   5796.469487   172.625649
# 4    1.0    0.000000  ...  1.264982  11.142517  23281.011643    56.105310
#
#      P0 [N]  DR [ ]  Material  d50 [mm]  φ [°]         f
# 0  0.046939     0.8      F110      0.12  39.33  0.798799
# 1  0.154249     0.8      F110      0.12  39.33  0.782783
# 2  0.720029     0.8      F110      0.12  39.33  0.887888
# 3  1.032218     0.8      F110      0.12  39.33  0.887888
# 4  2.017568     0.8      F110      0.12  39.33  0.955956
#
# [5 rows x 24 columns]

# %%
df.columns.values
# Out:
# array(['n [count]', 'α [°]', 'L [mm]', 'H [mm]', 'b [mm]', 'H/2b [ ]',
#        'Ls [mm]', 'd [mm]', 'P [ ]', '2π/n [rad]', 'γ [N/mm3]',
#        'Pmax [N]', 'δ(Pmax) [mm]', 'max(ktan) [N/mm]', "γAH' [N]",
#        'Nγ [ ]', 'Vroot [mm3]', 'F/Nroot [ ]', 'P0 [N]', 'DR [ ]',
#        'Material', 'd50 [mm]', 'φ [°]', 'f'], dtype=object)

# %%
df.drop(columns = ["H/2b [ ]", "Nγ [ ]", "F/Nroot [ ]", "P [ ]", "max(ktan) [N/mm]", "f"], inplace = True)

# %%
df.head()
# Out:
#   n [count]  α [°]  L [mm]  H [mm]   b [mm]    Ls [mm]  d [mm]  2π/n [rad]  \
# 0         3     15    75.0    90.0  19.4114  17.555563     5.0    2.094395
# 1         3     15    50.0    90.0  12.9410  41.703709     5.0    2.094395
# 2         6     15    75.0    90.0  19.4114  17.555563     5.0    1.047198
# 3         6     15    50.0    90.0  12.9410  41.703709     5.0    1.047198
# 4         F     15    75.0    90.0  19.4114  17.555563     5.0    0.000000
#
#    γ [N/mm3]   Pmax [N]  δ(Pmax) [mm]  γAH' [N]   Vroot [mm3]    P0 [N]  \
# 0   0.000016   9.080644      0.479395  1.264982   4534.350557  0.046939
# 1   0.000016   8.758713      0.645485  0.630942   3535.876732  0.154249
# 2   0.000016  11.753734      0.550172  1.264982   8267.564868  0.720029
# 3   0.000016  10.797683      0.495440  0.630942   5796.469487  1.032218
# 4   0.000016  14.095079      0.332745  1.264982  23281.011643  2.017568
#
#    DR [ ] Material  d50 [mm]  φ [°]
# 0     0.8     F110      0.12  39.33
# 1     0.8     F110      0.12  39.33
# 2     0.8     F110      0.12  39.33
# 3     0.8     F110      0.12  39.33
# 4     0.8     F110      0.12  39.33

# %%
df.to_csv("unique_data.csv", index = False)
