# %%
import pandas as pd
df = pd.read_excel("project_dataset.xlsx")
df.drop(columns = ["Unnamed: 24", "P_SLIPLINE [N]", "P_slip/gAH", "H/2b_updated","gammaAH_updated", "Unnamed: 30", "file"], inplace = True)
df.dropna(axis = 0, inplace = True)

# %%
df.to_csv("csv_project_dataset.csv", index = False)

# %%
#C:/Users/fmh/Desktop/CX4240/Project/csv_project_dataset(dc).csv
df = pd.read_csv("csv_project_dataset.csv")

# %%
df.columns.values
#df.sort_values(by = "L [mm]", ascending = True,  inplace = True)
#pd.options.display.max_columns = 30
# Out:
# array(['n [count]', 'α [°]', 'L [mm]', 'H [mm]', 'b [mm]', 'H/2b [ ]',
#        'Ls [mm]', 'd [mm]', 'P [ ]', '2π/n [rad]', 'γ [N/mm3]',
#        'Pmax [N]', 'δ(Pmax) [mm]', 'max(ktan) [N/mm]', "γAH' [N]",
#        'Nγ [ ]', 'Vroot [mm3]', 'F/Nroot [ ]', 'P0 [N]', 'DR [ ]',
#        'Material', 'd50 [mm]', 'φ [°]', 'f'], dtype=object)

# %%
#df.plot(x = "L [mm]", y = "Pmax [N]")

# %%
df.describe()
# Out:
#             α [°]      L [mm]      H [mm]      b [mm]    H/2b [ ]    Ls [mm]  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.00000
# mean    57.711864   42.252250  106.906780   30.210798    1.917789   82.61452
# std     23.794612   17.755636   28.912605    9.937226    0.716662   31.63750
# min     15.000000   12.500000   60.000000   12.500000    0.600000   16.69873
# 25%     30.000000   28.867500   90.000000   25.000000    1.800000   60.00000
# 50%     60.000000   37.500000   90.000000   25.000000    1.800000   76.69873
# 75%     90.000000   50.000000  120.000000   37.500000    2.000000   95.00000
# max     90.000000  100.000000  180.000000   53.033000    4.800000  151.13249
#
#            d [mm]       P [ ]  2π/n [rad]     γ [N/mm3]  ...  \
# count  177.000000  177.000000  177.000000  1.770000e+02  ...
# mean     5.543785    1.108757    1.133971  1.605233e-05  ...
# std      1.310682    0.262136    0.872689  5.225672e-07  ...
# ...

# %%
df.drop(columns = ["n [count]", "Material", "f", "H/2b [ ]", "max(ktan) [N/mm]", ], inplace = True)
df.head()
# Out:
#    α [°]  L [mm]  H [mm]   b [mm]    Ls [mm]  d [mm]  P [ ]  2π/n [rad]  \
# 0     15    75.0    90.0  19.4114  17.555563     5.0    1.0    2.094395
# 1     15    50.0    90.0  12.9410  41.703709     5.0    1.0    2.094395
# 2     15    75.0    90.0  19.4114  17.555563     5.0    1.0    1.047198
# 3     15    50.0    90.0  12.9410  41.703709     5.0    1.0    1.047198
# 4     15    75.0    90.0  19.4114  17.555563     5.0    1.0    0.000000
#
#    γ [N/mm3]   Pmax [N]  δ(Pmax) [mm]  γAH' [N]     Nγ [ ]   Vroot [mm3]  \
# 0   0.000016   9.080644      0.479395  1.264982   7.178479   4534.350557
# 1   0.000016   8.758713      0.645485  0.630942  13.881967   3535.876732
# 2   0.000016  11.753734      0.550172  1.264982   9.291625   8267.564868
# 3   0.000016  10.797683      0.495440  0.630942  17.113597   5796.469487
# 4   0.000016  14.095079      0.332745  1.264982  11.142517  23281.011643
#
#    F/Nroot [ ]    P0 [N]  DR [ ]  d50 [mm]  φ [°]
# ...

# %%
df.to_csv("csv_project_dataset.csv", index = False)
